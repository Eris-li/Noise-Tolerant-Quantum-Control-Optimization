# %%
import numpy as np
import rydcalc.rydcalc as rydcalc
Yb171 = rydcalc.Ytterbium171(cpp_numerov=True,use_db=False)

rydst_yb171 = Yb171.get_state((65,0,1,-3/2),tt='nljm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import numpy as np
# ----> 2 import rydcalc.rydcalc as rydcalc
#       3 Yb171 = rydcalc.Ytterbium171(cpp_numerov=True,use_db=False)
#       4
#       5 rydst_yb171 = Yb171.get_state((65,0,1,-3/2),tt='nljm')
#
# File ~/projects/Noise-Tolerant-Quantum-Control-Optimization/rydcalc/rydcalc/__init__.py:7
#       4 from .constants import *
#       6 from .single_basis import *
# ----> 7 from .pair_basis import *
#       9 from .hydrogen import *
#      10 from .alkali import *
#
# File ~/projects/Noise-Tolerant-Quantum-Control-Optimization/rydcalc/rydcalc/pair_basis.py:31
#      27     def __ne__(self,other):
#      28         return not self.__eq__(other)
# ---> 31 class pair_basis:
#      32     class pair_basis:
#      33         """
# ...
